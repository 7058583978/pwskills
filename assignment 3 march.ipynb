# %%
Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %%
ans]
1.SCATTERPLOT:it gives the data distribution in point form with x and y coordinate intersection
2.PAIRPLOT : it plots pairwise graph by default by generation grid of axes covering each dataset
3.JOINTPLOT : it gives graph of scatter pattern with one more addition giving varition along both axes
4.BARPLOT : it plots graph in bar format title on x axix and frequency on y axis
5.CATPLOT : it shows how a perticular category behaves with respect to dataset

# %%
Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
"timepoint" and y = "signal" for different events and regions.

Note: timepoint, signal, event, and region are columns in the fmri dataset.

# %%
import seaborn as sns 
import matplotlib.pyplot as bb

fmri = sns.load_dataset("fmri")

bb.subplot(1,2,1)
sns.lineplot(x = "timepoint",y = "signal",data=fmri,hue="event")

bb.subplot(1,2,2)
sns.lineplot(x = "timepoint",y = "signal",data=fmri,hue="region")
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
'pclass', y = 'age' and y = 'fare'.

Note: pclass, age, and fare are columns in the titanic dataset.

# %%
titanic = sns.load_dataset("titanic")

# %%
bb.subplot(1,2,1)
sns.boxplot(x="pclass",y="age",data=titanic)

bb.subplot(1,2,2)
sns.boxplot(x="pclass",y="fare",data=titanic)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %%
Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
parameter for the 'cut' column of the diamonds dataset.

# %%
diamonds=sns.load_dataset("diamonds")

# %%
sns.histplot(x='carat',y='price',data=diamonds,hue="cut")
# Out:
# <AxesSubplot: xlabel='carat', ylabel='price'>

# %%
Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
of the iris dataset.

# %%
iris = sns.load_dataset("iris")

# %%
sns.pairplot(iris,hue="species")

# %%
Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

flights=sns.load_dataset("flights")
flights= flights.pivot("year","month","passengers")
sns.heatmap(flights)
# Out:
# /tmp/ipykernel_91/3864344729.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights= flights.pivot("year","month","passengers")
# <AxesSubplot: xlabel='month', ylabel='year'>
