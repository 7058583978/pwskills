# %%
Q1. Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a
    scatter plot for age and fare columns in the titanic dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
titanic = sns.load_dataset("titanic")
fig = go.Figure()
fig.add_trace(go.Scatter(x=titanic.age,y=titanic.fare,mode="markers"))
fig.show()

# %% [markdown]
# ![newplot.png](attachment:0ff7af65-f3b3-4a70-b3b8-8a2fd576896d.png)

# %%
Q2. Using the tips dataset in the Plotly library, plot a box plot using Plotly express.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
tips = sns.load_dataset("tips")

# %%
fig = go.Figure()
fig.add_trace(go.Box(x=tips.total_bill,y=tips.tip,))
fig.show()

# %% [markdown]
# ![newplot (1).png](attachment:46b28d34-59f3-443f-9532-ef20d8889863.png)

# %%
Q3. Using the tips dataset in the Plotly library, Plot a histogram for x= "sex" and y="total_bill" column in
the tips dataset. Also, use the "smoker" column with the pattern_shape parameter and the "day"
column with the color parameter.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
tips = sns.load_dataset("tips")

# %%
import plotly.express as go

df = go.data.tips()
fig = go.histogram(df, x="sex", y="total_bill", color="day", pattern_shape="smoker")
fig.show()

# %% [markdown]
# ![newplot (2).png](attachment:5fbb3c3b-b558-4cf0-bb42-b95db36fd483.png)

# %%
Q4. Using the iris dataset in the Plotly library, Plot a scatter matrix plot, using the "species" column for
the color parameter.
Note: Use "sepal_length", "sepal_width", "petal_length", "petal_width" columns only with the
dimensions parameter.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
tips = sns.load_dataset("iris")

# %%
import plotly.express as go
df = go.data.iris()
fig = go.scatter_matrix(df,dimensions=["sepal_length", "sepal_width", "petal_length", "petal_width"], color="species")
fig.show()

# %% [markdown]
# ![newplot (3).png](attachment:2c032e60-54d3-4a09-be63-d16ea8aa54cd.png)

# %%
Q5. What is Distplot? Using Plotly express, plot a distplot.

# %%
distplot combine several statistical data and plot it agaist different shape

# %%
import plotly.figure_factory as ff
import numpy as np
tips = sns.load_dataset("tips")

x = tips.tip
hist_data = [x]
group_labels = ['distplot'] # name of the dataset

fig = ff.create_distplot(hist_data, group_labels)
fig.show()

# %% [markdown]
# ![newplot (4).png](attachment:d35559eb-4949-40f1-97d5-3c326d17041f.png)
