# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the
dataset have?

# %%
df = pd.read_excel("flight_price.xlsx")

# %%
df.shape,df.size
# Out:
# ((10683, 11), 117513)

# %%
so we have 10683 rows and 11 columns

# %%
Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the
distribution.

# %%
sns.histplot(data=df,x='Price',kde=True)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %%
Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
range in the dataset is 1759 to 79512 which are also min and max prices

# %%
Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
airlines.

# %%
sns.boxplot(data=df,x='Price',y='Airline')
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Airline'>

# %%
Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how
they may impact your analysis.

# %%
yes there are outliers present

# %%
sns.boxplot(data=df,x='Price',y='Airline')
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Airline'>

# %%
we have the price column to compare the data and due to outliers our mean price or say analysis
which are depend on price gets affected

# %%
Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset
to identify the peak travel season. What features would you analyze to identify the peak season, and how
would you present your findings to your boss?

# %%
df["Date_of_Journey"]=pd.to_datetime(df['Date_of_Journey'])
df['month']=df['Date_of_Journey'].dt.month

# %%
sns.histplot(data=df,x="month")
# Out:
# <AxesSubplot: xlabel='month', ylabel='Count'>

# %%
so from the data we can see that peak season for flights are march to july

# %%
Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
Price dataset to identify any trends in flight prices. What features would you analyze to identify these
trends, and what visualizations would you use to present your findings to your team?

# %%
plt.subplots(1,1,figsize=(10,10))
sns.histplot(data=df,x='Price',kde=True,hue="Destination")
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %%
we can see that as we increse the price from 15000 and above count decreses bu using different hue patterns
we can analyse the data

# %%
Q8. You are a data scientist working for an airline company, and you have been asked to analyze the
Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
identify these factors, and how would you present your findings to the management team?

# %%
plt.subplots(1,3,figsize=(10,10))
plt.subplot(1,3,1)
sns.histplot(data=df,x='Price',kde=True,hue="Destination")
plt.subplot(1,3,2)
sns.histplot(data=df,x='Price',kde=True,hue="Source")
plt.subplot(1,3,3)
sns.histplot(data=df,x='Price',kde=True,hue="Total_Stops")
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %%
there are various factors that affects price price such as source destination number of stops
as we can see in the above graphs

# %%
Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
the dataset have?

# %%
df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')

# %%
df.shape
# Out:
# (10841, 13)

# %%
so there are 10841 rows and 13 columns

# %%
Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different
app categories.

# %%
sns.histplot(data=df,x="Rating",kde=True,hue="Category")
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Count'>

# %%
sns.boxplot(data=df,x="Category",y="Rating")
# Out:
# <AxesSubplot: xlabel='Category', ylabel='Rating'>

# %%
Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
impact your analysis.

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
Rating            1474
Type                 1
Content Rating       1
Current Ver          8
Android Ver          3

# %%
among above three rating has the highest missing values and only this is going to affects our result 
suppose we need to find the variation with some variable and that data comes under missing then we cannot 
analyse the data

# %%
Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize
the relationship.

# %%
sns.scatterplot(data=df,x=df["Size"],y=df['Rating'])
# Out:
# <AxesSubplot: xlabel='Size', ylabel='Rating'>

# %%
so almost all the app has rating varies from 2.5 to 5

# %%
Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df1=df.copy()
df1=df1.drop(df1.index[10472])
df1["Size"]=df1["Size"].replace(".","")
df1["Size"]=df1["Size"].str.replace("M","000")
df1["Size"]=df1["Size"].str.replace("k","")
df1["Size"]=df1["Size"].replace("Varies with device",np.nan)
df1["Size"]=df1["Size"].astype(float)

# %%
df1["Price"]=df1["Price"].str.replace("$",'')
df1["Price"]=df1["Price"].astype(float)
# Out:
# /tmp/ipykernel_70/470954071.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df1["Price"]=df1["Price"].str.replace("$",'')

# %%
sns.countplot(data=df1,x="Price")
# Out:
# <AxesSubplot: xlabel='Price', ylabel='count'>

# %%
Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
with the highest number of installs.

# %%
category = pd.DataFrame(df1['Category'].value_counts())        #Dataframe of apps on the basis of category
category.rename(columns = {'Category':'Count'},inplace=True)

# %%
plt.figure(figsize=(25,25))
sns.barplot(x=category.index[:10], y ='Count',data = category[:10])
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the
Google Playstore dataset to identify the most popular app categories. How would you approach this
task, and what features would you analyze to make recommendations to the company?

# %%
to identify the most popular app categories on the Google Playstore, 
I would approach this task using the following steps:

Data collection: First, I would collect the relevant data from the Google Playstore dataset.
This dataset includes information about apps, such as their names, categories, ratings, reviews, and downloads.

Data cleaning and preprocessing: Next, I would clean and preprocess the data to remove any duplicates,
missing values, or irrelevant information that may affect the accuracy of the analysis.

Data analysis: Then, I would analyze the data to identify the most popular app categories by looking at
the frequency of each category in the dataset, the number of downloads and ratings for each category,
and the trends in the data over time.

Recommendation: Finally, based on the analysis, I would recommend the most popular app categories to the 
company and provide insights on the features that make these categories popular, such as their user interface, 
functionality, and marketing strategies.

# %%
Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the
most successful app developers. What features would you analyze to make recommendations to the
company, and what data visualizations would you use to present your findings?

# %%
To identify the most successful app developers on the Google Playstore, I would analyze the following features:

Number of downloads: I would analyze the total number of downloads for each developer's apps to identify 
the most successful developers.

Average rating: I would look at the average rating for each developer's apps to identify the developers 
with the highest ratings.

Number of reviews: I would analyze the total number of reviews for each developer's apps to identify the
developers with the most user engagement.

App categories: I would look at the categories of apps each developer has to identify if there are any 
particular categories in which the developer has the most success.

App update frequency: I would analyze the frequency of updates for each developer's apps to see if they
have a consistent update schedule.

Price: I would also look at the price of each developer's apps to see if they are pricing their apps competitively.

To present my findings, I would use the following data visualizations:

Bar chart: A bar chart would be suitable to show the total number of downloads for each developer, as well
as the total number of reviews.

Scatter plot: A scatter plot would be useful to show the relationship between the number of downloads and
the average rating for each developer.

Heatmap: A heatmap would be helpful to show the app categories that each developer has the most success in.

Line chart: A line chart would be suitable to show the frequency of updates for each developer's apps over time.

Box plot: A box plot would be useful to show the distribution of app prices for each developer.

# %%
Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to
launch a new app. What features would you analyze to make recommendations to the company, and
what data visualizations would you use to present your findings?

# %%
To identify the best time to launch a new app on the Google Playstore, I would analyze the following features:

App category: I would analyze the app categories that have the highest number of downloads to identify which 
categories are the most popular.

Downloads by time: I would analyze the number of downloads for each app category over time to identify the months
or seasons when the categories are the most popular.

User ratings: I would look at the average user ratings for each app category over time to identify any trends 
or patterns.

App updates: I would analyze the frequency of updates for each app category over time to see if there are any 
trends or patterns in the update schedules.

Reviews: I would analyze the reviews for each app category to identify any trends or patterns in the user feedback.

To present my findings, I would use the following data visualizations:

Line chart: A line chart would be suitable to show the trend of downloads over time for each app category,
as well as the trend of user ratings over time.

Bar chart: A bar chart would be useful to show the number of downloads for each app category in a particular
month or season.
